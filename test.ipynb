# %%
import proteovis as pv
import importlib
importlib.reload(pv.pycorn.utils)
# Out:
# <module 'proteovis.pycorn.utils' from 'c:\\Users\\jb60386\\Desktop\\testenv\\akta-db-venv\\AKTA-DB\\proteovis\\pycorn\\utils.py'>

# %%
data = pv.pycorn.load_uni_zip("static/uploads/test/raw_data/akta1.zip")
# Out:
# Chromatogram
# {'FormatVersion': '9', 'UNICORNVersion': '7.3.0.473'}
# added - orig data
# added - orig data
# added - orig data

# %%
df = pv.pycorn.utils.get_series_from_data(data,list(data.keys()),)
# Out:
# c:\Users\jb60386\Desktop\testenv\akta-db-venv\AKTA-DB\proteovis\pycorn\utils.py:32: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df = df.interpolate(method='linear')

# %%
frac_df = pv.pycorn.utils.get_fraction_rectangle(df)
# Out:
# Error: The first value of 'Fractions' column is NaN. Please check your data.
# c:\Users\jb60386\Desktop\testenv\akta-db-venv\AKTA-DB\proteovis\pycorn\utils.py:85: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Fractions"] = df["Fractions"].fillna(method='ffill')

# %%
frac_df = pv.pycorn.utils.pooling_fraction(frac_df,start="1.B.2",end="1.B.5")
frac_df = pv.pycorn.utils.pooling_fraction(frac_df,start="1.B.10",end="1.B.11",name="pool2")
frac_df
# Out:
#    Fraction_Start   Start_mL      End_mL      Max_UV Color_code  \
# 0           1.A.1  -0.000426    1.999608    0.030576    #750ffe
# 1           1.A.2   1.999608    3.999568    0.057902    #6b1ffe
# 2           1.A.3   3.999568    5.999498    0.394412    #612efd
# 3           1.A.4   5.999498    7.999408    0.670828    #573efd
# 4           1.A.5   7.999408    9.994688    0.758782    #4d4dfb
# 5     Waste(Frac)   9.994688   10.006288    0.750330    #435cfa
# 6           1.A.6  10.006288   12.006218    0.805312    #396af9
# 7           1.A.7  12.006218   14.006958    0.775002    #2f78f7
# 8           1.A.8  14.006958   16.006928    0.681707    #2388f4
# 9           1.A.9  16.006928   18.006848    0.560983    #1995f2
# 10         1.A.10  18.006848   20.006768    0.590820    #0fa2ef
# 11         1.A.11  20.006768   22.006728    0.569868    #05aeed
# 12         1.A.12  22.006728   23.973278    0.549120    #04b9ea
# 13    Waste(Frac)  23.973278   23.986668    0.529674    #0ec3e6
# ...
